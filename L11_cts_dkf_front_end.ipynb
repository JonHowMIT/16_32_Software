# %% [markdown]
# # Compare Approximate Discrete Solution to CTS Solution

# %%
dt = 0.25
tf = 1.5
set_cts_noise = False
# %store dt
# %store tf
# %store set_cts_noise

# %run ./L11_CTS_DKF.ipynb
# Out:
# Stored 'dt' (float)
# Stored 'tf' (float)
# Stored 'set_cts_noise' (bool)
# Running Python: 3.8.16
# Using dt =  0.25
# Set discrete noise value
# Steady State Continuous Q(t) = 0.7071
# Average of Steady State Discrete Q[k] = 0.7508

# %%
dt = 0.1
# %run ./L11_CTS_DKF.ipynb
# Out:
# Running Python: 3.8.16
# Using dt =  0.1
# Set discrete noise value
# Steady State Continuous Q(t) = 0.4472
# Average of Steady State Discrete Q[k] = 0.4583

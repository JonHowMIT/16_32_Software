# %% [markdown]
# # Compare Approximate Discrete Solution to CTS Solution

# %%
dt = .25
# %store dt 
# %run ./L11_CTS_DKF.ipynb
# Out:
# Stored 'dt' (float)
# Running Python: 3.8.16
# 0.25
# Steady State Continuous Q(t) = 0.7071
# Average of Steady State Discrete Q[k] = 0.7500

# %%
dt = 0.001
# %run ./L11_CTS_DKF.ipynb
# Out:
# Running Python: 3.8.16
# 0.001
# Steady State Continuous Q(t) = 0.0447
# Average of Steady State Discrete Q[k] = 0.0447
